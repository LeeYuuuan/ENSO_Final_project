# %%
from train_model import train_mul_models

# %%
Number = 0
train_mul_models()
# Out:
# Train samples: 80, Valid samples: 20
# Train samples: 3716, Valid samples: 929
# Epoch 1/200 : Train Loss 0.630371, Valid Loss 0.706431
# Epoch 2/200 : Train Loss 0.558596, Valid Loss 0.460516
# Epoch 3/200 : Train Loss 0.516496, Valid Loss 0.531550
# Epoch 4/200 : Train Loss 0.507766, Valid Loss 0.509992
# Epoch 5/200 : Train Loss 0.490384, Valid Loss 0.529481
# Epoch 6/200 : Train Loss 0.470446, Valid Loss 0.539516
# Epoch 7/200 : Train Loss 0.453627, Valid Loss 1.593513
# Epoch 8/200 : Train Loss 0.447663, Valid Loss 0.806905
# Epoch 9/200 : Train Loss 0.403187, Valid Loss 1.227596
# Epoch 10/200 : Train Loss 0.389517, Valid Loss 4.876725
# Epoch 11/200 : Train Loss 0.393303, Valid Loss 0.602724
# Epoch 12/200 : Train Loss 0.375659, Valid Loss 3.097886
# Epoch 13/200 : Train Loss 0.314252, Valid Loss 0.495652
# Epoch 14/200 : Train Loss 0.286626, Valid Loss 1.393093
# Epoch 15/200 : Train Loss 0.259272, Valid Loss 6.698798
# Epoch 16/200 : Train Loss 0.246797, Valid Loss 2.998593
# ...

# %%
Number = 1
n_epochs = 500
train_mul_models(model_info=[
    {"model_name": "LSTM", "dataset_type": "ALL", "deactivate_feature": None, "optimizer_type": "Adam", "lr": 0.0001, "n_epochs": n_epochs},
    {"model_name": "LSTM", "dataset_type": "ALL", "deactivate_feature": None, "optimizer_type": "SGD", "lr": 0.0001, "n_epochs": n_epochs},
    {"model_name": "LSTM", "dataset_type": "ALL", "deactivate_feature": None, "optimizer_type": "Adam", "lr": 0.001, "n_epochs": n_epochs},
    {"model_name": "LSTM", "dataset_type": "ALL", "deactivate_feature": None, "optimizer_type": "SGD", "lr": 0.001, "n_epochs": n_epochs},
    
    ],Number=Number)
# Out:
# Train samples: 80, Valid samples: 20
# Train samples: 3716, Valid samples: 929
# Epoch 1/500 : Train Loss 0.679377, Valid Loss 0.436881
# Epoch 2/500 : Train Loss 0.524422, Valid Loss 0.397981
# Epoch 3/500 : Train Loss 0.447006, Valid Loss 0.383103
# Epoch 4/500 : Train Loss 0.381172, Valid Loss 0.402564
# Epoch 5/500 : Train Loss 0.325139, Valid Loss 0.419832
# Epoch 6/500 : Train Loss 0.280860, Valid Loss 0.419713
# Epoch 7/500 : Train Loss 0.224346, Valid Loss 0.468406
# Epoch 8/500 : Train Loss 0.181377, Valid Loss 0.482731
# Epoch 9/500 : Train Loss 0.141985, Valid Loss 0.497239
# Epoch 10/500 : Train Loss 0.123617, Valid Loss 0.498323
# Epoch 11/500 : Train Loss 0.100166, Valid Loss 0.522931
# Epoch 12/500 : Train Loss 0.087780, Valid Loss 0.508921
# Epoch 13/500 : Train Loss 0.074727, Valid Loss 0.500477
# Epoch 14/500 : Train Loss 0.067272, Valid Loss 0.505297
# Epoch 15/500 : Train Loss 0.059818, Valid Loss 0.515498
# Epoch 16/500 : Train Loss 0.061472, Valid Loss 0.523456
# ...

# %%
Number
# Out:
# 1

# %%
Number = 2
n_epochs = 500
train_mul_models(model_info=[
    {"model_name": "Transformer", "dataset_type": "ALL", "deactivate_feature": None, "optimizer_type": "Adam", "lr": 0.0001, "n_epochs": n_epochs},
    {"model_name": "Transformer", "dataset_type": "ALL", "deactivate_feature": None, "optimizer_type": "SGD", "lr": 0.0001, "n_epochs": n_epochs},
    {"model_name": "Transformer", "dataset_type": "ALL", "deactivate_feature": None, "optimizer_type": "Adam", "lr": 0.001, "n_epochs": n_epochs},
    {"model_name": "Transformer", "dataset_type": "ALL", "deactivate_feature": None, "optimizer_type": "SGD", "lr": 0.001, "n_epochs": n_epochs},
    
    ],Number=Number)
# Out:
# Train samples: 80, Valid samples: 20
# Train samples: 3716, Valid samples: 929
# Epoch 1/500 : Train Loss 0.611892, Valid Loss 0.400444
# Epoch 2/500 : Train Loss 0.471160, Valid Loss 0.446541
# Epoch 3/500 : Train Loss 0.416455, Valid Loss 0.428652
# Epoch 4/500 : Train Loss 0.366810, Valid Loss 0.471317
# Epoch 5/500 : Train Loss 0.312507, Valid Loss 0.494902
# Epoch 6/500 : Train Loss 0.263437, Valid Loss 0.500502
# Epoch 7/500 : Train Loss 0.214066, Valid Loss 0.492450
# Epoch 8/500 : Train Loss 0.179966, Valid Loss 0.559252
# Epoch 9/500 : Train Loss 0.137822, Valid Loss 0.533070
# Epoch 10/500 : Train Loss 0.113666, Valid Loss 0.523373
# Epoch 11/500 : Train Loss 0.090317, Valid Loss 0.541518
# Epoch 12/500 : Train Loss 0.077137, Valid Loss 0.523056
# Epoch 13/500 : Train Loss 0.075400, Valid Loss 0.516987
# Epoch 14/500 : Train Loss 0.067441, Valid Loss 0.521475
# Epoch 15/500 : Train Loss 0.061087, Valid Loss 0.526529
# Epoch 16/500 : Train Loss 0.055700, Valid Loss 0.512971
# ...

# %%
Number = 3
n_epochs = 500
train_mul_models(model_info=[
    {"model_name": "Transformer_CNN", "dataset_type": "ALL", "deactivate_feature": None, "optimizer_type": "Adam", "lr": 0.0001, "n_epochs": n_epochs},
    {"model_name": "Transformer_CNN", "dataset_type": "ALL", "deactivate_feature": None, "optimizer_type": "SGD", "lr": 0.0001, "n_epochs": n_epochs},
    {"model_name": "Transformer_CNN", "dataset_type": "ALL", "deactivate_feature": None, "optimizer_type": "Adam", "lr": 0.001, "n_epochs": n_epochs},
    {"model_name": "Transformer_CNN", "dataset_type": "ALL", "deactivate_feature": None, "optimizer_type": "SGD", "lr": 0.001, "n_epochs": n_epochs},
    
    ],Number=Number)
# Out:
# Train samples: 80, Valid samples: 20
# Train samples: 3716, Valid samples: 929
# Epoch 1/500 : Train Loss 0.791337, Valid Loss 0.576702
# Epoch 2/500 : Train Loss 0.739184, Valid Loss 0.533663
# Epoch 3/500 : Train Loss 0.606824, Valid Loss 0.444465
# Epoch 4/500 : Train Loss 0.557019, Valid Loss 0.423361
# Epoch 5/500 : Train Loss 0.511056, Valid Loss 0.400771
# Epoch 6/500 : Train Loss 0.470837, Valid Loss 0.407891
# Epoch 7/500 : Train Loss 0.426998, Valid Loss 0.452785
# Epoch 8/500 : Train Loss 0.376394, Valid Loss 0.441509
# Epoch 9/500 : Train Loss 0.281667, Valid Loss 0.438973
# Epoch 10/500 : Train Loss 0.199414, Valid Loss 0.470112
# Epoch 11/500 : Train Loss 0.142254, Valid Loss 0.459996
# Epoch 12/500 : Train Loss 0.109577, Valid Loss 0.458074
# Epoch 13/500 : Train Loss 0.076781, Valid Loss 0.461917
# Epoch 14/500 : Train Loss 0.062826, Valid Loss 0.471445
# Epoch 15/500 : Train Loss 0.051361, Valid Loss 0.471871
# Epoch 16/500 : Train Loss 0.042323, Valid Loss 0.471734
# ...

# %%
Number = 4
train_mul_models(model_info=[
                            {"model_name": "CNN", "dataset_type": "ALL", "deactivate_feature": None, "optimizer_type": "Adam", "lr": 0.0001, "n_epochs": n_epochs},
                            {"model_name": "CNN", "dataset_type": "ALL", "deactivate_feature": ['ua'], "optimizer_type": "Adam", "lr": 0.0001, "n_epochs": n_epochs},
                            {"model_name": "CNN", "dataset_type": "ALL", "deactivate_feature": ['va'], "optimizer_type": "Adam", "lr": 0.0001, "n_epochs": n_epochs},
                            {"model_name": "CNN", "dataset_type": "ALL", "deactivate_feature": ['t300'], "optimizer_type": "Adam", "lr": 0.0001, "n_epochs": n_epochs},
                            {"model_name": "CNN", "dataset_type": "ALL", "deactivate_feature": ['sst'], "optimizer_type": "Adam", "lr": 0.0001, "n_epochs": n_epochs},
])
# Out:
# Train samples: 80, Valid samples: 20
# Train samples: 3716, Valid samples: 929
# Epoch 1/500 : Train Loss 0.698005, Valid Loss 0.499285
# Epoch 2/500 : Train Loss 0.593812, Valid Loss 0.473681
# Epoch 3/500 : Train Loss 0.565823, Valid Loss 0.549528
# Epoch 4/500 : Train Loss 0.533014, Valid Loss 0.768531
# Epoch 5/500 : Train Loss 0.503769, Valid Loss 0.724417
# Epoch 6/500 : Train Loss 0.481507, Valid Loss 0.464929
# Epoch 7/500 : Train Loss 0.457644, Valid Loss 0.764684
# Epoch 8/500 : Train Loss 0.446707, Valid Loss 3.377965
# Epoch 9/500 : Train Loss 0.421233, Valid Loss 0.582237
# Epoch 10/500 : Train Loss 0.394150, Valid Loss 1.524233
# Epoch 11/500 : Train Loss 0.376584, Valid Loss 1.415217
# Epoch 12/500 : Train Loss 0.331230, Valid Loss 1.419313
# Epoch 13/500 : Train Loss 0.312959, Valid Loss 3.015402
# Epoch 14/500 : Train Loss 0.269525, Valid Loss 1.448322
# Epoch 15/500 : Train Loss 0.235038, Valid Loss 4.626858
# Epoch 16/500 : Train Loss 0.225641, Valid Loss 1.423935
# ...

# %%
Number = 5
n_epochs = 200
train_mul_models(model_info=[
                            {"model_name": "LSTM", "dataset_type": "ALL", "deactivate_feature": None, "optimizer_type": "SGD", "lr": 0.003, "n_epochs": n_epochs},
                            {"model_name": "LSTM", "dataset_type": "ALL", "deactivate_feature": ['ua'], "optimizer_type": "SGD", "lr": 0.003, "n_epochs": n_epochs},
                            {"model_name": "LSTM", "dataset_type": "ALL", "deactivate_feature": ['va'], "optimizer_type": "SGD", "lr": 0.003, "n_epochs": n_epochs},
                            {"model_name": "LSTM", "dataset_type": "ALL", "deactivate_feature": ['t300'], "optimizer_type": "SGD", "lr": 0.003, "n_epochs": n_epochs},
                            {"model_name": "LSTM", "dataset_type": "ALL", "deactivate_feature": ['sst'], "optimizer_type": "SGD", "lr": 0.003, "n_epochs": n_epochs},
])
# Out:
# Train samples: 80, Valid samples: 20
# Train samples: 3716, Valid samples: 929
# Epoch 1/200 : Train Loss 0.778249, Valid Loss 0.547925
# Epoch 2/200 : Train Loss 0.784010, Valid Loss 0.547024
# Epoch 3/200 : Train Loss 0.769367, Valid Loss 0.546178
# Epoch 4/200 : Train Loss 0.773032, Valid Loss 0.545376
# Epoch 5/200 : Train Loss 0.770373, Valid Loss 0.544609
# Epoch 6/200 : Train Loss 0.778088, Valid Loss 0.543868
# Epoch 7/200 : Train Loss 0.764632, Valid Loss 0.543162
# Epoch 8/200 : Train Loss 0.759443, Valid Loss 0.542481
# Epoch 9/200 : Train Loss 0.756674, Valid Loss 0.541835
# Epoch 10/200 : Train Loss 0.755204, Valid Loss 0.541172
# Epoch 11/200 : Train Loss 0.763080, Valid Loss 0.540522
# Epoch 12/200 : Train Loss 0.753279, Valid Loss 0.539887
# Epoch 13/200 : Train Loss 0.752410, Valid Loss 0.539253
# Epoch 14/200 : Train Loss 0.750577, Valid Loss 0.538608
# Epoch 15/200 : Train Loss 0.745814, Valid Loss 0.537978
# Epoch 16/200 : Train Loss 0.738045, Valid Loss 0.537322
# ...

# %%
Number = 6
n_epochs = 200
train_mul_models(model_info=[
                            {"model_name": "CNN", "dataset_type": "ALL", "deactivate_feature": None, "optimizer_type": "SGD", "lr": 0.001, "n_epochs": n_epochs},
                            {"model_name": "LSTM", "dataset_type": "ALL", "deactivate_feature": None, "optimizer_type": "SGD", "lr": 0.0001, "n_epochs": n_epochs},
                            {"model_name": "Transformer", "dataset_type": "ALL", "deactivate_feature": None, "optimizer_type": "Adam", "lr": 0.0001, "n_epochs": n_epochs},
])
# Out:
# Train samples: 80, Valid samples: 20
# Train samples: 3716, Valid samples: 929
# Epoch 1/200 : Train Loss 0.800484, Valid Loss 0.554160
# Epoch 2/200 : Train Loss 0.791998, Valid Loss 0.553389
# Epoch 3/200 : Train Loss 0.782533, Valid Loss 0.552522
# Epoch 4/200 : Train Loss 0.788921, Valid Loss 0.551918
# Epoch 5/200 : Train Loss 0.772181, Valid Loss 0.551326
# Epoch 6/200 : Train Loss 0.776242, Valid Loss 0.551082
# Epoch 7/200 : Train Loss 0.770824, Valid Loss 0.550871
# Epoch 8/200 : Train Loss 0.778488, Valid Loss 0.550476
# Epoch 9/200 : Train Loss 0.765053, Valid Loss 0.550229
# Epoch 10/200 : Train Loss 0.762762, Valid Loss 0.550039
# Epoch 11/200 : Train Loss 0.765140, Valid Loss 0.549844
# Epoch 12/200 : Train Loss 0.778185, Valid Loss 0.549769
# Epoch 13/200 : Train Loss 0.759525, Valid Loss 0.549518
# Epoch 14/200 : Train Loss 0.759075, Valid Loss 0.549146
# Epoch 15/200 : Train Loss 0.756167, Valid Loss 0.548814
# Epoch 16/200 : Train Loss 0.747880, Valid Loss 0.548369
# ...

# %%
Number = 5
n_epochs = 200
train_mul_models(model_info=[
                            {"model_name": "Transformer", "dataset_type": "ALL", "deactivate_feature": None, "optimizer_type": "Adam", "lr": 0.0001, "n_epochs": n_epochs},
                            {"model_name": "Transformer", "dataset_type": "ALL", "deactivate_feature": ['ua'], "optimizer_type": "Adam", "lr": 0.0001, "n_epochs": n_epochs},
                            {"model_name": "Transformer", "dataset_type": "ALL", "deactivate_feature": ['va'], "optimizer_type": "Adam", "lr": 0.0001, "n_epochs": n_epochs},
                            {"model_name": "Transformer", "dataset_type": "ALL", "deactivate_feature": ['t300'], "optimizer_type": "Adam", "lr": 0.0001, "n_epochs": n_epochs},
                            {"model_name": "Transformer", "dataset_type": "ALL", "deactivate_feature": ['sst'], "optimizer_type": "Adam", "lr": 0.0001, "n_epochs": n_epochs},
], Number=6)
# Out:
# Train samples: 80, Valid samples: 20
# Train samples: 3716, Valid samples: 929
# Epoch 1/200 : Train Loss 0.613522, Valid Loss 0.416746
# Epoch 2/200 : Train Loss 0.462397, Valid Loss 0.432640
# Epoch 3/200 : Train Loss 0.410437, Valid Loss 0.412832
# Epoch 4/200 : Train Loss 0.352318, Valid Loss 0.478520
# Epoch 5/200 : Train Loss 0.304590, Valid Loss 0.480428
# Epoch 6/200 : Train Loss 0.252062, Valid Loss 0.511449
# Epoch 7/200 : Train Loss 0.202296, Valid Loss 0.531233
# Epoch 8/200 : Train Loss 0.168493, Valid Loss 0.523643
# Epoch 9/200 : Train Loss 0.133804, Valid Loss 0.555498
# Epoch 10/200 : Train Loss 0.117929, Valid Loss 0.506278
# Epoch 11/200 : Train Loss 0.092305, Valid Loss 0.514092
# Epoch 12/200 : Train Loss 0.077337, Valid Loss 0.508540
# Epoch 13/200 : Train Loss 0.077912, Valid Loss 0.529433
# Epoch 14/200 : Train Loss 0.069698, Valid Loss 0.519528
# Epoch 15/200 : Train Loss 0.060533, Valid Loss 0.540336
# Epoch 16/200 : Train Loss 0.062500, Valid Loss 0.502817
# ...

# %%
Number = 5
n_epochs = 200
train_mul_models(model_info=[
                            {"model_name": "Transformer", "dataset_type": "ALL", "deactivate_feature": None, "optimizer_type": "Adam", "lr": 0.0001, "n_epochs": n_epochs},
                            {"model_name": "Transformer", "dataset_type": "ALL", "deactivate_feature": ['ua'], "optimizer_type": "Adam", "lr": 0.0001, "n_epochs": n_epochs},
                            {"model_name": "Transformer", "dataset_type": "ALL", "deactivate_feature": ['va'], "optimizer_type": "Adam", "lr": 0.0001, "n_epochs": n_epochs},
                            {"model_name": "Transformer", "dataset_type": "ALL", "deactivate_feature": ['t300'], "optimizer_type": "Adam", "lr": 0.0001, "n_epochs": n_epochs},
                            {"model_name": "Transformer", "dataset_type": "ALL", "deactivate_feature": ['sst'], "optimizer_type": "Adam", "lr": 0.0001, "n_epochs": n_epochs},
])

# %%
train_mul_models(model_info=[
                            {"model_name": "CNN", "dataset_type": "ALL", "deactivate_feature": None, "optimizer_type": "Adam", "lr": 0.001},
                            {"model_name": "CNN", "dataset_type": "ALL", "deactivate_feature": None, "optimizer_type": "Adam", "lr": 0.0001},
                            {"model_name": "CNN", "dataset_type": "ALL", "deactivate_feature": None, "optimizer_type": "SGD", "lr": 0.0001}
])
